# %% [markdown]
# ## Import libraries

# %%
from tabula import read_pdf
import pandas as pd

# %% [markdown]
# ## Read table from PDF file

# %%
table_from_pdf = read_pdf('example-2.pdf')

# %% [markdown]
# ## Show table

# %%
table_from_pdf
# Out:
#      Zones     102     103     104     105     106     107     108     124
# 0   Letter  $55.60  $60.79  $69.28  $72.02  $72.87  $77.17  $79.32  $87.59
# 1   1 Lbs.   60.62   75.33   89.28   96.41   99.92  108.59  110.73  118.03
# 2        2   61.03   75.92   94.74  101.30  106.91  111.83  120.21  126.53
# 3        3   64.73   80.57  101.69  111.50  117.63  125.23  128.61  135.77
# 4        4   67.44   82.98  110.19  119.23  122.48  133.43  137.31  147.66
# 5        5   68.25   83.23  111.86  120.03  123.86  134.75  138.38  157.11
# 6        6   73.33   87.34  122.06  135.30  140.14  150.26  155.45  166.30
# 7        7   73.86   90.57  126.18  140.47  144.67  155.52  164.01  176.25
# 8        8   74.24   92.30  129.84  147.68  153.11  162.94  168.19  184.40
# 9        9   74.80   92.73  136.78  148.41  153.97  164.49  171.18  194.06
# 10      10   75.20   93.20  137.86  150.42  156.19  166.67  173.09  204.48
# ...

# %% [markdown]
# ## Save table in Excel File

# %%
export_excel = table_from_second_page.to_excel ('table_second_page_example.xlsx', index = None, header=True)
